# %%
from macrosim.SeriesAccessor import SeriesAccessor
from macrosim.BaseVarSelector import BaseVarSelector

import pandas as pd
import numpy as np
import datetime as dt
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
fred = SeriesAccessor(
    key_path='../fred_key.env',
    key_name='FRED_KEY'
)

start = dt.datetime.fromisoformat('2002-01-01')
end = dt.datetime.fromisoformat('2024-01-01')

df = fred.get_series(
    series_ids = ['NETEXP', 'CIVPART', 'CORESTICKM159SFRBATL', 'LES1252881600Q', 'SPPOPGROWUSA', 'A264RX1A020NBEA', 'GDPC1'],
    series_alias=[None, None, 'CPI', 'RWAGE', 'POPGROWTH', 'I_C', 'RGDP'],
    reindex_freq='QS',
    date_range=(start, end),

)
df = fred.fill(
    data=df,
    methods=[None, None, None, None, 'ffill', 'divide', None]
)
df
# Out:
#              NETEXP  CIVPART       CPI  RWAGE  POPGROWTH       I_C       RGDP
# 2002-01-01 -386.884     66.5  3.557463  341.0   0.927797   80.2338  14372.785
# 2002-04-01 -428.259     66.7  3.465822  339.0   0.927797   80.2338  14460.848
# 2002-07-01 -447.548     66.5  3.263706  337.0   0.927797   80.2338  14519.633
# 2002-10-01 -496.289     66.6  2.937194  336.0   0.927797   80.2338  14537.580
# 2003-01-01 -525.262     66.4  2.778159  335.0   0.859482   82.2952  14614.141
# ...             ...      ...       ...    ...        ...       ...        ...
# 2023-01-01 -813.648     62.4  6.488339  364.0   0.491925  126.6340  22403.435
# 2023-04-01 -803.479     62.6  6.267738  365.0   0.491925  126.6340  22539.418
# 2023-07-01 -781.091     62.6  5.402919  366.0   0.491925  126.6340  22780.933
# 2023-10-01 -791.152     62.7  4.882717  370.0   0.491925  126.6340  22960.600
# 2024-01-01 -841.569     62.5  4.601332  365.0   0.491925  324.5150  23053.545
#
# [89 rows x 7 columns]

# %%
bvd = BaseVarSelector(df=df)
G = bvd.granger_matrix()
G
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.6819  , p=0.1982  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=1.7413  , p=0.1870  , df=1
# likelihood ratio test: chi2=1.7243  , p=0.1891  , df=1
# parameter F test:         F=1.6819  , p=0.1982  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.6626  , p=0.0300  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=7.7718  , p=0.0205  , df=2
# likelihood ratio test: chi2=7.4441  , p=0.0242  , df=2
# parameter F test:         F=3.6626  , p=0.0300  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.5871  , p=0.0589  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=8.4491  , p=0.0376  , df=3
# likelihood ratio test: chi2=8.0594  , p=0.0448  , df=3
# parameter F test:         F=2.5871  , p=0.0589  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.3696  , p=0.0599  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=10.6008 , p=0.0314  , df=4
# likelihood ratio test: chi2=9.9901  , p=0.0406  , df=4
# parameter F test:         F=2.3696  , p=0.0599  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.0127  , p=0.0868  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=11.5799 , p=0.0410  , df=5
# likelihood ratio test: chi2=10.8482 , p=0.0545  , df=5
# parameter F test:         F=2.0127  , p=0.0868  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0084  , p=0.0760  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=14.2886 , p=0.0266  , df=6
# likelihood ratio test: chi2=13.1838 , p=0.0402  , df=6
# parameter F test:         F=2.0084  , p=0.0760  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.7791  , p=0.1060  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=15.2418 , p=0.0330  , df=7
# likelihood ratio test: chi2=13.9795 , p=0.0515  , df=7
# parameter F test:         F=1.7791  , p=0.1060  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.6451  , p=0.0143  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=26.7815 , p=0.0008  , df=8
# likelihood ratio test: chi2=23.1382 , p=0.0032  , df=8
# parameter F test:         F=2.6451  , p=0.0143  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.4039  , p=0.0210  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=28.3739 , p=0.0008  , df=9
# likelihood ratio test: chi2=24.2848 , p=0.0039  , df=9
# parameter F test:         F=2.4039  , p=0.0210  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.7775  , p=0.1860  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=1.8403  , p=0.1749  , df=1
# likelihood ratio test: chi2=1.8213  , p=0.1772  , df=1
# parameter F test:         F=1.7775  , p=0.1860  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7331  , p=0.4835  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=1.5556  , p=0.4594  , df=2
# likelihood ratio test: chi2=1.5419  , p=0.4626  , df=2
# parameter F test:         F=0.7331  , p=0.4835  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5966  , p=0.1969  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=5.2141  , p=0.1568  , df=3
# likelihood ratio test: chi2=5.0621  , p=0.1673  , df=3
# parameter F test:         F=1.5966  , p=0.1969  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3361  , p=0.2643  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=5.9774  , p=0.2008  , df=4
# likelihood ratio test: chi2=5.7766  , p=0.2165  , df=4
# parameter F test:         F=1.3361  , p=0.2643  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1635  , p=0.3354  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=6.6942  , p=0.2444  , df=5
# likelihood ratio test: chi2=6.4408  , p=0.2657  , df=5
# parameter F test:         F=1.1635  , p=0.3354  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3719  , p=0.2381  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=9.7603  , p=0.1351  , df=6
# likelihood ratio test: chi2=9.2277  , p=0.1612  , df=6
# parameter F test:         F=1.3719  , p=0.2381  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.1889  , p=0.0461  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=18.7530 , p=0.0090  , df=7
# likelihood ratio test: chi2=16.8881 , p=0.0181  , df=7
# parameter F test:         F=2.1889  , p=0.0461  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.0319  , p=0.0564  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=20.5728 , p=0.0084  , df=8
# likelihood ratio test: chi2=18.3325 , p=0.0189  , df=8
# parameter F test:         F=2.0319  , p=0.0564  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.9646  , p=0.0592  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=23.1890 , p=0.0058  , df=9
# likelihood ratio test: chi2=20.3629 , p=0.0158  , df=9
# parameter F test:         F=1.9646  , p=0.0592  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.5497  , p=0.0073  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=7.8162  , p=0.0052  , df=1
# likelihood ratio test: chi2=7.4883  , p=0.0062  , df=1
# parameter F test:         F=7.5497  , p=0.0073  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.7553  , p=0.0275  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=7.9686  , p=0.0186  , df=2
# likelihood ratio test: chi2=7.6245  , p=0.0221  , df=2
# parameter F test:         F=3.7553  , p=0.0275  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.3974  , p=0.0743  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=7.8294  , p=0.0497  , df=3
# likelihood ratio test: chi2=7.4933  , p=0.0577  , df=3
# parameter F test:         F=2.3974  , p=0.0743  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8108  , p=0.1355  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=8.1009  , p=0.0880  , df=4
# likelihood ratio test: chi2=7.7378  , p=0.1017  , df=4
# parameter F test:         F=1.8108  , p=0.1355  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5416  , p=0.1876  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=8.8695  , p=0.1144  , df=5
# likelihood ratio test: chi2=8.4318  , p=0.1340  , df=5
# parameter F test:         F=1.5416  , p=0.1876  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2660  , p=0.2843  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=9.0067  , p=0.1732  , df=6
# likelihood ratio test: chi2=8.5507  , p=0.2005  , df=6
# parameter F test:         F=1.2660  , p=0.2843  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0530  , p=0.4035  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=9.0208  , p=0.2512  , df=7
# likelihood ratio test: chi2=8.5583  , p=0.2859  , df=7
# parameter F test:         F=1.0530  , p=0.4035  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.0215  , p=0.0577  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=20.4678 , p=0.0087  , df=8
# likelihood ratio test: chi2=18.2487 , p=0.0194  , df=8
# parameter F test:         F=2.0215  , p=0.0577  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0366  , p=0.0501  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=24.0388 , p=0.0042  , df=9
# likelihood ratio test: chi2=21.0190 , p=0.0126  , df=9
# parameter F test:         F=2.0366  , p=0.0501  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1790  , p=0.6733  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=0.1853  , p=0.6668  , df=1
# likelihood ratio test: chi2=0.1851  , p=0.6670  , df=1
# parameter F test:         F=0.1790  , p=0.6733  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4738  , p=0.6243  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=1.0055  , p=0.6049  , df=2
# likelihood ratio test: chi2=0.9997  , p=0.6066  , df=2
# parameter F test:         F=0.4738  , p=0.6243  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4197  , p=0.7394  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=1.3707  , p=0.7124  , df=3
# likelihood ratio test: chi2=1.3599  , p=0.7150  , df=3
# parameter F test:         F=0.4197  , p=0.7394  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2756  , p=0.8929  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=1.2329  , p=0.8727  , df=4
# likelihood ratio test: chi2=1.2240  , p=0.8741  , df=4
# parameter F test:         F=0.2756  , p=0.8929  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1521  , p=0.3410  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=6.6288  , p=0.2497  , df=5
# likelihood ratio test: chi2=6.3802  , p=0.2710  , df=5
# parameter F test:         F=1.1521  , p=0.3410  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5290  , p=0.1815  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=10.8776 , p=0.0922  , df=6
# likelihood ratio test: chi2=10.2215 , p=0.1156  , df=6
# parameter F test:         F=1.5290  , p=0.1815  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.9204  , p=0.0799  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=16.4524 , p=0.0213  , df=7
# likelihood ratio test: chi2=14.9940 , p=0.0361  , df=7
# parameter F test:         F=1.9204  , p=0.0799  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.6386  , p=0.1315  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=16.5912 , p=0.0347  , df=8
# likelihood ratio test: chi2=15.0934 , p=0.0574  , df=8
# parameter F test:         F=1.6386  , p=0.1315  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6346  , p=0.1255  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=19.2941 , p=0.0228  , df=9
# likelihood ratio test: chi2=17.2847 , p=0.0444  , df=9
# parameter F test:         F=1.6346  , p=0.1255  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0613  , p=0.8050  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=0.0635  , p=0.8011  , df=1
# likelihood ratio test: chi2=0.0635  , p=0.8011  , df=1
# parameter F test:         F=0.0613  , p=0.8050  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2680  , p=0.7656  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=0.5687  , p=0.7525  , df=2
# likelihood ratio test: chi2=0.5668  , p=0.7532  , df=2
# parameter F test:         F=0.2680  , p=0.7656  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5107  , p=0.6760  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=1.6680  , p=0.6441  , df=3
# likelihood ratio test: chi2=1.6520  , p=0.6477  , df=3
# parameter F test:         F=0.5107  , p=0.6760  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5979  , p=0.6652  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=2.6749  , p=0.6136  , df=4
# likelihood ratio test: chi2=2.6337  , p=0.6209  , df=4
# parameter F test:         F=0.5979  , p=0.6652  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.7596  , p=0.1319  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=10.1238 , p=0.0718  , df=5
# likelihood ratio test: chi2=9.5587  , p=0.0888  , df=5
# parameter F test:         F=1.7596  , p=0.1319  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0589  , p=0.0691  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=14.6479 , p=0.0232  , df=6
# likelihood ratio test: chi2=13.4897 , p=0.0359  , df=6
# parameter F test:         F=2.0589  , p=0.0691  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.9272  , p=0.0788  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=16.5111 , p=0.0208  , df=7
# likelihood ratio test: chi2=15.0429 , p=0.0355  , df=7
# parameter F test:         F=1.9272  , p=0.0788  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.6547  , p=0.1271  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=16.7537 , p=0.0328  , df=8
# likelihood ratio test: chi2=15.2281 , p=0.0549  , df=8
# parameter F test:         F=1.6547  , p=0.1271  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3613  , p=0.2256  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=16.0680 , p=0.0655  , df=9
# likelihood ratio test: chi2=14.6423 , p=0.1012  , df=9
# parameter F test:         F=1.3613  , p=0.2256  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2591  , p=0.6121  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=0.2682  , p=0.6045  , df=1
# likelihood ratio test: chi2=0.2678  , p=0.6048  , df=1
# parameter F test:         F=0.2591  , p=0.6121  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5645  , p=0.5709  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=1.1978  , p=0.5494  , df=2
# likelihood ratio test: chi2=1.1896  , p=0.5517  , df=2
# parameter F test:         F=0.5645  , p=0.5709  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3039  , p=0.8225  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=0.9924  , p=0.8031  , df=3
# likelihood ratio test: chi2=0.9867  , p=0.8045  , df=3
# parameter F test:         F=0.3039  , p=0.8225  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2932  , p=0.8816  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=1.3115  , p=0.8594  , df=4
# likelihood ratio test: chi2=1.3015  , p=0.8611  , df=4
# parameter F test:         F=0.2932  , p=0.8816  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5072  , p=0.7699  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=2.9184  , p=0.7126  , df=5
# likelihood ratio test: chi2=2.8689  , p=0.7202  , df=5
# parameter F test:         F=0.5072  , p=0.7699  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4447  , p=0.8463  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=3.1640  , p=0.7880  , df=6
# likelihood ratio test: chi2=3.1052  , p=0.7955  , df=6
# parameter F test:         F=0.4447  , p=0.8463  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5281  , p=0.8102  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=4.5243  , p=0.7178  , df=7
# likelihood ratio test: chi2=4.4039  , p=0.7323  , df=7
# parameter F test:         F=0.5281  , p=0.8102  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.8455  , p=0.0091  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=28.8107 , p=0.0003  , df=8
# likelihood ratio test: chi2=24.6490 , p=0.0018  , df=8
# parameter F test:         F=2.8455  , p=0.0091  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.7716  , p=0.0087  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=32.7143 , p=0.0001  , df=9
# likelihood ratio test: chi2=27.4264 , p=0.0012  , df=9
# parameter F test:         F=2.7716  , p=0.0087  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4572  , p=0.2307  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=1.5087  , p=0.2193  , df=1
# likelihood ratio test: chi2=1.4959  , p=0.2213  , df=1
# parameter F test:         F=1.4572  , p=0.2307  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3227  , p=0.1044  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=4.9286  , p=0.0851  , df=2
# likelihood ratio test: chi2=4.7941  , p=0.0910  , df=2
# parameter F test:         F=2.3227  , p=0.1044  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.4451  , p=0.0206  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=11.2511 , p=0.0104  , df=3
# likelihood ratio test: chi2=10.5736 , p=0.0143  , df=3
# parameter F test:         F=3.4451  , p=0.0206  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.8922  , p=0.0276  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=12.9387 , p=0.0116  , df=4
# likelihood ratio test: chi2=12.0437 , p=0.0170  , df=4
# parameter F test:         F=2.8922  , p=0.0276  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.1743  , p=0.0662  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=12.5098 , p=0.0284  , df=5
# likelihood ratio test: chi2=11.6615 , p=0.0397  , df=5
# parameter F test:         F=2.1743  , p=0.0662  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0768  , p=0.0669  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=14.7751 , p=0.0221  , df=6
# likelihood ratio test: chi2=13.5978 , p=0.0345  , df=6
# parameter F test:         F=2.0768  , p=0.0669  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.7629  , p=0.1095  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=15.1027 , p=0.0347  , df=7
# likelihood ratio test: chi2=13.8621 , p=0.0537  , df=7
# parameter F test:         F=1.7629  , p=0.1095  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.4828  , p=0.1811  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=15.0132 , p=0.0589  , df=8
# likelihood ratio test: chi2=13.7730 , p=0.0879  , df=8
# parameter F test:         F=1.4828  , p=0.1811  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3976  , p=0.2093  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=16.4960 , p=0.0572  , df=9
# likelihood ratio test: chi2=14.9980 , p=0.0910  , df=9
# parameter F test:         F=1.3976  , p=0.2093  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2529  , p=0.6163  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=0.2619  , p=0.6088  , df=1
# likelihood ratio test: chi2=0.2615  , p=0.6091  , df=1
# parameter F test:         F=0.2529  , p=0.6163  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1219  , p=0.3306  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=2.3807  , p=0.3041  , df=2
# likelihood ratio test: chi2=2.3487  , p=0.3090  , df=2
# parameter F test:         F=1.1219  , p=0.3306  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4624  , p=0.2312  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=4.7758  , p=0.1890  , df=3
# likelihood ratio test: chi2=4.6479  , p=0.1995  , df=3
# parameter F test:         F=1.4624  , p=0.2312  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.6129  , p=0.1797  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=7.2154  , p=0.1249  , df=4
# likelihood ratio test: chi2=6.9254  , p=0.1399  , df=4
# parameter F test:         F=1.6129  , p=0.1797  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2748  , p=0.2841  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=7.3344  , p=0.1969  , df=5
# likelihood ratio test: chi2=7.0317  , p=0.2183  , df=5
# parameter F test:         F=1.2748  , p=0.2841  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0732  , p=0.3869  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=7.6348  , p=0.2661  , df=6
# likelihood ratio test: chi2=7.3038  , p=0.2937  , df=6
# parameter F test:         F=1.0732  , p=0.3869  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8454  , p=0.5540  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=7.2426  , p=0.4041  , df=7
# likelihood ratio test: chi2=6.9404  , p=0.4351  , df=7
# parameter F test:         F=0.8454  , p=0.5540  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7261  , p=0.6679  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=7.3515  , p=0.4992  , df=8
# likelihood ratio test: chi2=7.0368  , p=0.5327  , df=8
# parameter F test:         F=0.7261  , p=0.6679  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2063  , p=0.3079  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=14.2387 , p=0.1141  , df=9
# likelihood ratio test: chi2=13.1043 , p=0.1579  , df=9
# parameter F test:         F=1.2063  , p=0.3079  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0480  , p=0.8272  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=0.0497  , p=0.8236  , df=1
# likelihood ratio test: chi2=0.0497  , p=0.8237  , df=1
# parameter F test:         F=0.0480  , p=0.8272  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4627  , p=0.6312  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=0.9818  , p=0.6121  , df=2
# likelihood ratio test: chi2=0.9763  , p=0.6138  , df=2
# parameter F test:         F=0.4627  , p=0.6312  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4815  , p=0.6961  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=1.5724  , p=0.6657  , df=3
# likelihood ratio test: chi2=1.5582  , p=0.6689  , df=3
# parameter F test:         F=0.4815  , p=0.6961  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0641  , p=0.3802  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=4.7604  , p=0.3128  , df=4
# likelihood ratio test: chi2=4.6319  , p=0.3272  , df=4
# parameter F test:         F=1.0641  , p=0.3802  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9362  , p=0.4628  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=5.3862  , p=0.3706  , df=5
# likelihood ratio test: chi2=5.2206  , p=0.3896  , df=5
# parameter F test:         F=0.9362  , p=0.4628  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7367  , p=0.6218  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=5.2412  , p=0.5133  , df=6
# likelihood ratio test: chi2=5.0824  , p=0.5333  , df=6
# parameter F test:         F=0.7367  , p=0.6218  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0213  , p=0.4246  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=8.7494  , p=0.2712  , df=7
# likelihood ratio test: chi2=8.3133  , p=0.3058  , df=7
# parameter F test:         F=1.0213  , p=0.4246  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9697  , p=0.4676  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=9.8179  , p=0.2780  , df=8
# likelihood ratio test: chi2=9.2670  , p=0.3203  , df=8
# parameter F test:         F=0.9697  , p=0.4676  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8566  , p=0.5681  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=10.1105 , p=0.3416  , df=9
# likelihood ratio test: chi2=9.5208  , p=0.3907  , df=9
# parameter F test:         F=0.8566  , p=0.5681  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7969  , p=0.3745  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=0.8251  , p=0.3637  , df=1
# likelihood ratio test: chi2=0.8212  , p=0.3648  , df=1
# parameter F test:         F=0.7969  , p=0.3745  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=10.3706 , p=0.0001  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=22.0058 , p=0.0000  , df=2
# likelihood ratio test: chi2=19.6179 , p=0.0001  , df=2
# parameter F test:         F=10.3706 , p=0.0001  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=7.6881  , p=0.0001  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=25.1079 , p=0.0000  , df=3
# likelihood ratio test: chi2=22.0293 , p=0.0001  , df=3
# parameter F test:         F=7.6881  , p=0.0001  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=9.8902  , p=0.0000  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=44.2458 , p=0.0000  , df=4
# likelihood ratio test: chi2=35.6205 , p=0.0000  , df=4
# parameter F test:         F=9.8902  , p=0.0000  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=13.1383 , p=0.0000  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=75.5902 , p=0.0000  , df=5
# likelihood ratio test: chi2=53.9106 , p=0.0000  , df=5
# parameter F test:         F=13.1383 , p=0.0000  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=11.3441 , p=0.0000  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=80.7055 , p=0.0000  , df=6
# likelihood ratio test: chi2=56.3759 , p=0.0000  , df=6
# parameter F test:         F=11.3441 , p=0.0000  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=9.5996  , p=0.0000  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=82.2418 , p=0.0000  , df=7
# likelihood ratio test: chi2=56.9589 , p=0.0000  , df=7
# parameter F test:         F=9.5996  , p=0.0000  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=8.7381  , p=0.0000  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=88.4735 , p=0.0000  , df=8
# likelihood ratio test: chi2=59.7980 , p=0.0000  , df=8
# parameter F test:         F=8.7381  , p=0.0000  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=8.3786  , p=0.0000  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=98.8953 , p=0.0000  , df=9
# likelihood ratio test: chi2=64.3819 , p=0.0000  , df=9
# parameter F test:         F=8.3786  , p=0.0000  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.6772  , p=0.0069  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=7.9481  , p=0.0048  , df=1
# likelihood ratio test: chi2=7.6094  , p=0.0058  , df=1
# parameter F test:         F=7.6772  , p=0.0069  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.4887  , p=0.0893  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=5.2808  , p=0.0713  , df=2
# likelihood ratio test: chi2=5.1268  , p=0.0770  , df=2
# parameter F test:         F=2.4887  , p=0.0893  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4550  , p=0.2332  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=4.7518  , p=0.1909  , df=3
# likelihood ratio test: chi2=4.6252  , p=0.2014  , df=3
# parameter F test:         F=1.4550  , p=0.2332  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9289  , p=0.4518  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=4.1557  , p=0.3853  , df=4
# likelihood ratio test: chi2=4.0573  , p=0.3983  , df=4
# parameter F test:         F=0.9289  , p=0.4518  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5562  , p=0.1833  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=8.9536  , p=0.1109  , df=5
# likelihood ratio test: chi2=8.5078  , p=0.1304  , df=5
# parameter F test:         F=1.5562  , p=0.1833  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3368  , p=0.0409  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=16.6246 , p=0.0108  , df=6
# likelihood ratio test: chi2=15.1532 , p=0.0191  , df=6
# parameter F test:         F=2.3368  , p=0.0409  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.2529  , p=0.0404  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=19.3006 , p=0.0073  , df=7
# likelihood ratio test: chi2=17.3326 , p=0.0154  , df=7
# parameter F test:         F=2.2529  , p=0.0404  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.1330  , p=0.0451  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=21.5970 , p=0.0057  , df=8
# likelihood ratio test: chi2=19.1451 , p=0.0141  , df=8
# parameter F test:         F=2.1330  , p=0.0451  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6912  , p=0.1107  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=19.9616 , p=0.0182  , df=9
# likelihood ratio test: chi2=17.8207 , p=0.0373  , df=9
# parameter F test:         F=1.6912  , p=0.1107  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.3838  , p=0.0693  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=3.5032  , p=0.0612  , df=1
# likelihood ratio test: chi2=3.4353  , p=0.0638  , df=1
# parameter F test:         F=3.3838  , p=0.0693  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.9473  , p=0.0231  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=8.3761  , p=0.0152  , df=2
# likelihood ratio test: chi2=7.9970  , p=0.0183  , df=2
# parameter F test:         F=3.9473  , p=0.0231  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.9114  , p=0.1345  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=6.2424  , p=0.1004  , df=3
# likelihood ratio test: chi2=6.0262  , p=0.1103  , df=3
# parameter F test:         F=1.9114  , p=0.1345  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5628  , p=0.1929  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=6.9915  , p=0.1363  , df=4
# likelihood ratio test: chi2=6.7188  , p=0.1515  , df=4
# parameter F test:         F=1.5628  , p=0.1929  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.4386  , p=0.2207  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=8.2767  , p=0.1416  , df=5
# likelihood ratio test: chi2=7.8939  , p=0.1622  , df=5
# parameter F test:         F=1.4386  , p=0.2207  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.2093  , p=0.3119  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=8.6034  , p=0.1971  , df=6
# likelihood ratio test: chi2=8.1861  , p=0.2248  , df=6
# parameter F test:         F=1.2093  , p=0.3119  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1471  , p=0.3450  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=9.8270  , p=0.1986  , df=7
# likelihood ratio test: chi2=9.2813  , p=0.2331  , df=7
# parameter F test:         F=1.1471  , p=0.3450  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1263  , p=0.3581  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=11.4033 , p=0.1799  , df=8
# likelihood ratio test: chi2=10.6688 , p=0.2212  , df=8
# parameter F test:         F=1.1263  , p=0.3581  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3905  , p=0.2124  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=16.4122 , p=0.0588  , df=9
# likelihood ratio test: chi2=14.9285 , p=0.0929  , df=9
# parameter F test:         F=1.3905  , p=0.2124  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=37.2531 , p=0.0000  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=38.5679 , p=0.0000  , df=1
# likelihood ratio test: chi2=31.9829 , p=0.0000  , df=1
# parameter F test:         F=37.2531 , p=0.0000  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=11.7045 , p=0.0000  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=24.8364 , p=0.0000  , df=2
# likelihood ratio test: chi2=21.8482 , p=0.0000  , df=2
# parameter F test:         F=11.7045 , p=0.0000  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=7.5685  , p=0.0002  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=24.7172 , p=0.0000  , df=3
# likelihood ratio test: chi2=21.7264 , p=0.0001  , df=3
# parameter F test:         F=7.5685  , p=0.0002  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=7.4576  , p=0.0000  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=33.3629 , p=0.0000  , df=4
# likelihood ratio test: chi2=28.1439 , p=0.0000  , df=4
# parameter F test:         F=7.4576  , p=0.0000  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.8378  , p=0.0007  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=27.8342 , p=0.0000  , df=5
# likelihood ratio test: chi2=24.0408 , p=0.0002  , df=5
# parameter F test:         F=4.8378  , p=0.0007  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=5.0322  , p=0.0002  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=35.8006 , p=0.0000  , df=6
# likelihood ratio test: chi2=29.7643 , p=0.0000  , df=6
# parameter F test:         F=5.0322  , p=0.0002  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=4.3998  , p=0.0005  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=37.6938 , p=0.0000  , df=7
# likelihood ratio test: chi2=31.0138 , p=0.0001  , df=7
# parameter F test:         F=4.3998  , p=0.0005  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=4.4991  , p=0.0002  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=45.5537 , p=0.0000  , df=8
# likelihood ratio test: chi2=36.1436 , p=0.0000  , df=8
# parameter F test:         F=4.4991  , p=0.0002  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=4.0119  , p=0.0005  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=47.3534 , p=0.0000  , df=9
# likelihood ratio test: chi2=37.1951 , p=0.0000  , df=9
# parameter F test:         F=4.0119  , p=0.0005  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.6975  , p=0.0114  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=6.9339  , p=0.0085  , df=1
# likelihood ratio test: chi2=6.6743  , p=0.0098  , df=1
# parameter F test:         F=6.6975  , p=0.0114  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.7730  , p=0.0109  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=10.1282 , p=0.0063  , df=2
# likelihood ratio test: chi2=9.5807  , p=0.0083  , df=2
# parameter F test:         F=4.7730  , p=0.0109  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.9073  , p=0.0398  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=9.4949  , p=0.0234  , df=3
# likelihood ratio test: chi2=9.0064  , p=0.0292  , df=3
# parameter F test:         F=2.9073  , p=0.0398  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.8975  , p=0.0062  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=17.4360 , p=0.0016  , df=4
# likelihood ratio test: chi2=15.8599 , p=0.0032  , df=4
# parameter F test:         F=3.8975  , p=0.0062  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.9224  , p=0.0185  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=16.8136 , p=0.0049  , df=5
# likelihood ratio test: chi2=15.3264 , p=0.0091  , df=5
# parameter F test:         F=2.9224  , p=0.0185  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.4531  , p=0.0328  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=17.4517 , p=0.0078  , df=6
# likelihood ratio test: chi2=15.8394 , p=0.0146  , df=6
# parameter F test:         F=2.4531  , p=0.0328  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.1213  , p=0.0530  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=18.1736 , p=0.0112  , df=7
# likelihood ratio test: chi2=16.4152 , p=0.0216  , df=7
# parameter F test:         F=2.1213  , p=0.0530  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.7838  , p=0.0967  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=18.0614 , p=0.0208  , df=8
# likelihood ratio test: chi2=16.3045 , p=0.0382  , df=8
# parameter F test:         F=1.7838  , p=0.0967  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.6256  , p=0.0123  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=30.9903 , p=0.0003  , df=9
# likelihood ratio test: chi2=26.1933 , p=0.0019  , df=9
# parameter F test:         F=2.6256  , p=0.0123  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4158  , p=0.5208  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=0.4304  , p=0.5118  , df=1
# likelihood ratio test: chi2=0.4294  , p=0.5123  , df=1
# parameter F test:         F=0.4158  , p=0.5208  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9552  , p=0.3890  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=2.0268  , p=0.3630  , df=2
# likelihood ratio test: chi2=2.0035  , p=0.3672  , df=2
# parameter F test:         F=0.9552  , p=0.3890  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.5964  , p=0.0171  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=11.7453 , p=0.0083  , df=3
# likelihood ratio test: chi2=11.0095 , p=0.0117  , df=3
# parameter F test:         F=3.5964  , p=0.0171  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=9.2732  , p=0.0000  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=41.4853 , p=0.0000  , df=4
# likelihood ratio test: chi2=33.7853 , p=0.0000  , df=4
# parameter F test:         F=9.2732  , p=0.0000  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.7816  , p=0.0008  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=27.5103 , p=0.0000  , df=5
# likelihood ratio test: chi2=23.7972 , p=0.0002  , df=5
# parameter F test:         F=4.7816  , p=0.0008  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=4.0911  , p=0.0014  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=29.1050 , p=0.0001  , df=6
# likelihood ratio test: chi2=24.9494 , p=0.0003  , df=6
# parameter F test:         F=4.0911  , p=0.0014  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=4.2429  , p=0.0006  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=36.3498 , p=0.0000  , df=7
# likelihood ratio test: chi2=30.0879 , p=0.0001  , df=7
# parameter F test:         F=4.2429  , p=0.0006  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=4.0500  , p=0.0006  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=41.0065 , p=0.0000  , df=8
# likelihood ratio test: chi2=33.1797 , p=0.0001  , df=8
# parameter F test:         F=4.0500  , p=0.0006  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.6948  , p=0.0010  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=43.6111 , p=0.0000  , df=9
# likelihood ratio test: chi2=34.8091 , p=0.0001  , df=9
# parameter F test:         F=3.6948  , p=0.0010  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=29.8735 , p=0.0000  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=30.9279 , p=0.0000  , df=1
# likelihood ratio test: chi2=26.5039 , p=0.0000  , df=1
# parameter F test:         F=29.8735 , p=0.0000  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=13.3473 , p=0.0000  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=28.3224 , p=0.0000  , df=2
# likelihood ratio test: chi2=24.5186 , p=0.0000  , df=2
# parameter F test:         F=13.3473 , p=0.0000  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=16.4471 , p=0.0000  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=53.7133 , p=0.0000  , df=3
# likelihood ratio test: chi2=41.7311 , p=0.0000  , df=3
# parameter F test:         F=16.4471 , p=0.0000  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=11.7516 , p=0.0000  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=52.5730 , p=0.0000  , df=4
# likelihood ratio test: chi2=40.9278 , p=0.0000  , df=4
# parameter F test:         F=11.7516 , p=0.0000  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=6.6897  , p=0.0000  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=38.4885 , p=0.0000  , df=5
# likelihood ratio test: chi2=31.6848 , p=0.0000  , df=5
# parameter F test:         F=6.6897  , p=0.0000  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=6.6337  , p=0.0000  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=47.1942 , p=0.0000  , df=6
# likelihood ratio test: chi2=37.3655 , p=0.0000  , df=6
# parameter F test:         F=6.6337  , p=0.0000  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=5.6622  , p=0.0000  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=48.5090 , p=0.0000  , df=7
# likelihood ratio test: chi2=38.1073 , p=0.0000  , df=7
# parameter F test:         F=5.6622  , p=0.0000  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=5.1088  , p=0.0001  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=51.7270 , p=0.0000  , df=8
# likelihood ratio test: chi2=40.0015 , p=0.0000  , df=8
# parameter F test:         F=5.1088  , p=0.0001  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.6935  , p=0.0010  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=43.5954 , p=0.0000  , df=9
# likelihood ratio test: chi2=34.7990 , p=0.0001  , df=9
# parameter F test:         F=3.6935  , p=0.0010  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.6807  , p=0.0333  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=4.8459  , p=0.0277  , df=1
# likelihood ratio test: chi2=4.7172  , p=0.0299  , df=1
# parameter F test:         F=4.6807  , p=0.0333  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4190  , p=0.2478  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=3.0110  , p=0.2219  , df=2
# likelihood ratio test: chi2=2.9600  , p=0.2276  , df=2
# parameter F test:         F=1.4190  , p=0.2478  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8121  , p=0.4909  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=2.6522  , p=0.4484  , df=3
# likelihood ratio test: chi2=2.6121  , p=0.4554  , df=3
# parameter F test:         F=0.8121  , p=0.4909  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5348  , p=0.7105  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=2.3926  , p=0.6640  , df=4
# likelihood ratio test: chi2=2.3595  , p=0.6700  , df=4
# parameter F test:         F=0.5348  , p=0.7105  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0719  , p=0.3831  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=6.1670  , p=0.2903  , df=5
# likelihood ratio test: chi2=5.9511  , p=0.3110  , df=5
# parameter F test:         F=1.0719  , p=0.3831  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7955  , p=0.5766  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=5.6592  , p=0.4624  , df=6
# likelihood ratio test: chi2=5.4746  , p=0.4845  , df=6
# parameter F test:         F=0.7955  , p=0.5766  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7572  , p=0.6248  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=6.4870  , p=0.4842  , df=7
# likelihood ratio test: chi2=6.2432  , p=0.5117  , df=7
# parameter F test:         F=0.7572  , p=0.6248  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6477  , p=0.7347  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=6.5582  , p=0.5850  , df=8
# likelihood ratio test: chi2=6.3062  , p=0.6130  , df=8
# parameter F test:         F=0.6477  , p=0.7347  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5918  , p=0.7988  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=6.9848  , p=0.6387  , df=9
# likelihood ratio test: chi2=6.6966  , p=0.6687  , df=9
# parameter F test:         F=0.5918  , p=0.7988  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.2407  , p=0.0086  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=7.4963  , p=0.0062  , df=1
# likelihood ratio test: chi2=7.1940  , p=0.0073  , df=1
# parameter F test:         F=7.2407  , p=0.0086  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.3701  , p=0.0157  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=9.2732  , p=0.0097  , df=2
# likelihood ratio test: chi2=8.8115  , p=0.0122  , df=2
# parameter F test:         F=4.3701  , p=0.0157  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2905  , p=0.0847  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=7.4803  , p=0.0581  , df=3
# likelihood ratio test: chi2=7.1727  , p=0.0666  , df=3
# parameter F test:         F=2.2905  , p=0.0847  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=6.7691  , p=0.0001  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=30.2828 , p=0.0000  , df=4
# likelihood ratio test: chi2=25.9026 , p=0.0000  , df=4
# parameter F test:         F=6.7691  , p=0.0001  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.7546  , p=0.0044  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=21.6016 , p=0.0006  , df=5
# likelihood ratio test: chi2=19.2240 , p=0.0017  , df=5
# parameter F test:         F=3.7546  , p=0.0044  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.5283  , p=0.0042  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=25.1011 , p=0.0003  , df=6
# likelihood ratio test: chi2=21.9308 , p=0.0012  , df=6
# parameter F test:         F=3.5283  , p=0.0042  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.4562  , p=0.0032  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=29.6096 , p=0.0001  , df=7
# likelihood ratio test: chi2=25.2796 , p=0.0007  , df=7
# parameter F test:         F=3.4562  , p=0.0032  , df_denom=67, df_num=7
#
# ...
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8787  , p=0.1085  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=10.8092 , p=0.0553  , df=5
# likelihood ratio test: chi2=10.1682 , p=0.0706  , df=5
# parameter F test:         F=1.8787  , p=0.1085  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.1229  , p=0.0613  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=15.1030 , p=0.0195  , df=6
# likelihood ratio test: chi2=13.8757 , p=0.0311  , df=6
# parameter F test:         F=2.1229  , p=0.0613  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.8942  , p=0.0842  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=16.2280 , p=0.0231  , df=7
# likelihood ratio test: chi2=14.8069 , p=0.0386  , df=7
# parameter F test:         F=1.8942  , p=0.0842  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.6861  , p=0.1190  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=17.0716 , p=0.0294  , df=8
# likelihood ratio test: chi2=15.4911 , p=0.0503  , df=8
# parameter F test:         F=1.6861  , p=0.1190  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.9497  , p=0.0613  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=23.0127 , p=0.0062  , df=9
# likelihood ratio test: chi2=20.2261 , p=0.0166  , df=9
# parameter F test:         F=1.9497  , p=0.0613  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=17.6221 , p=0.0001  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=18.2441 , p=0.0000  , df=1
# likelihood ratio test: chi2=16.5794 , p=0.0000  , df=1
# parameter F test:         F=17.6221 , p=0.0001  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=13.1026 , p=0.0000  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=27.8030 , p=0.0000  , df=2
# likelihood ratio test: chi2=24.1260 , p=0.0000  , df=2
# parameter F test:         F=13.1026 , p=0.0000  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=8.5662  , p=0.0001  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=27.9758 , p=0.0000  , df=3
# likelihood ratio test: chi2=24.2209 , p=0.0000  , df=3
# parameter F test:         F=8.5662  , p=0.0001  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=6.6187  , p=0.0001  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=29.6101 , p=0.0000  , df=4
# likelihood ratio test: chi2=25.4052 , p=0.0000  , df=4
# parameter F test:         F=6.6187  , p=0.0001  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=5.1631  , p=0.0004  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=29.7058 , p=0.0000  , df=5
# likelihood ratio test: chi2=25.4350 , p=0.0001  , df=5
# parameter F test:         F=5.1631  , p=0.0004  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=4.4926  , p=0.0007  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=31.9616 , p=0.0000  , df=6
# likelihood ratio test: chi2=27.0378 , p=0.0001  , df=6
# parameter F test:         F=4.4926  , p=0.0007  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.7353  , p=0.0018  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=32.0009 , p=0.0000  , df=7
# likelihood ratio test: chi2=27.0180 , p=0.0003  , df=7
# parameter F test:         F=3.7353  , p=0.0018  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.1065  , p=0.0050  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=31.4531 , p=0.0001  , df=8
# likelihood ratio test: chi2=26.5750 , p=0.0008  , df=8
# parameter F test:         F=3.1065  , p=0.0050  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.7108  , p=0.0101  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=31.9964 , p=0.0002  , df=9
# likelihood ratio test: chi2=26.9152 , p=0.0014  , df=9
# parameter F test:         F=2.7108  , p=0.0101  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2952  , p=0.5883  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=0.3056  , p=0.5804  , df=1
# likelihood ratio test: chi2=0.3051  , p=0.5807  , df=1
# parameter F test:         F=0.2952  , p=0.5883  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5998  , p=0.2082  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=3.3947  , p=0.1832  , df=2
# likelihood ratio test: chi2=3.3301  , p=0.1892  , df=2
# parameter F test:         F=1.5998  , p=0.2082  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1230  , p=0.3449  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=3.6675  , p=0.2997  , df=3
# likelihood ratio test: chi2=3.5915  , p=0.3091  , df=3
# parameter F test:         F=1.1230  , p=0.3449  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7657  , p=0.5509  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=3.4253  , p=0.4893  , df=4
# likelihood ratio test: chi2=3.3581  , p=0.4998  , df=4
# parameter F test:         F=0.7657  , p=0.5509  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4892  , p=0.7833  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=2.8148  , p=0.7285  , df=5
# likelihood ratio test: chi2=2.7686  , p=0.7356  , df=5
# parameter F test:         F=0.4892  , p=0.7833  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5199  , p=0.7913  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=3.6989  , p=0.7174  , df=6
# likelihood ratio test: chi2=3.6188  , p=0.7281  , df=6
# parameter F test:         F=0.5199  , p=0.7913  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3921  , p=0.9038  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=3.3590  , p=0.8499  , df=7
# likelihood ratio test: chi2=3.2920  , p=0.8567  , df=7
# parameter F test:         F=0.3921  , p=0.9038  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.3448  , p=0.9448  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=3.4914  , p=0.8999  , df=8
# likelihood ratio test: chi2=3.4183  , p=0.9054  , df=8
# parameter F test:         F=0.3448  , p=0.9448  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7405  , p=0.6705  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=8.7402  , p=0.4616  , df=9
# likelihood ratio test: chi2=8.2949  , p=0.5047  , df=9
# parameter F test:         F=0.7405  , p=0.6705  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.6586  , p=0.0069  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=7.9289  , p=0.0049  , df=1
# likelihood ratio test: chi2=7.5918  , p=0.0059  , df=1
# parameter F test:         F=7.6586  , p=0.0069  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.1027  , p=0.0502  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=6.5838  , p=0.0372  , df=2
# likelihood ratio test: chi2=6.3465  , p=0.0419  , df=2
# parameter F test:         F=3.1027  , p=0.0502  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.7284  , p=0.1679  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=5.6447  , p=0.1302  , df=3
# likelihood ratio test: chi2=5.4672  , p=0.1406  , df=3
# parameter F test:         F=1.7284  , p=0.1679  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3345  , p=0.2649  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=5.9702  , p=0.2014  , df=4
# likelihood ratio test: chi2=5.7698  , p=0.2170  , df=4
# parameter F test:         F=1.3345  , p=0.2649  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0427  , p=0.3993  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=5.9989  , p=0.3063  , df=5
# likelihood ratio test: chi2=5.7944  , p=0.3267  , df=5
# parameter F test:         F=1.0427  , p=0.3993  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0341  , p=0.4108  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=7.3565  , p=0.2891  , df=6
# likelihood ratio test: chi2=7.0486  , p=0.3164  , df=6
# parameter F test:         F=1.0341  , p=0.4108  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7116  , p=0.6623  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=6.0962  , p=0.5286  , df=7
# likelihood ratio test: chi2=5.8802  , p=0.5538  , df=7
# parameter F test:         F=0.7116  , p=0.6623  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6269  , p=0.7521  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=6.3476  , p=0.6084  , df=8
# likelihood ratio test: chi2=6.1112  , p=0.6348  , df=8
# parameter F test:         F=0.6269  , p=0.7521  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5792  , p=0.8090  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=6.8359  , p=0.6542  , df=9
# likelihood ratio test: chi2=6.5595  , p=0.6829  , df=9
# parameter F test:         F=0.5792  , p=0.8090  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.1771  , p=0.1438  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=2.2540  , p=0.1333  , df=1
# likelihood ratio test: chi2=2.2256  , p=0.1357  , df=1
# parameter F test:         F=2.1771  , p=0.1438  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=12.3452 , p=0.0000  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=26.1960 , p=0.0000  , df=2
# likelihood ratio test: chi2=22.8995 , p=0.0000  , df=2
# parameter F test:         F=12.3452 , p=0.0000  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=9.2943  , p=0.0000  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=30.3535 , p=0.0000  , df=3
# likelihood ratio test: chi2=25.9966 , p=0.0000  , df=3
# parameter F test:         F=9.2943  , p=0.0000  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=13.3327 , p=0.0000  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=59.6463 , p=0.0000  , df=4
# likelihood ratio test: chi2=45.1894 , p=0.0000  , df=4
# parameter F test:         F=13.3327 , p=0.0000  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=18.4541 , p=0.0000  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=106.1742, p=0.0000  , df=5
# likelihood ratio test: chi2=68.6384 , p=0.0000  , df=5
# parameter F test:         F=18.4541 , p=0.0000  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=15.7435 , p=0.0000  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=112.0037, p=0.0000  , df=6
# likelihood ratio test: chi2=70.8967 , p=0.0000  , df=6
# parameter F test:         F=15.7435 , p=0.0000  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=13.8514 , p=0.0000  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=118.6674, p=0.0000  , df=7
# likelihood ratio test: chi2=73.3842 , p=0.0000  , df=7
# parameter F test:         F=13.8514 , p=0.0000  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=12.4620 , p=0.0000  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=126.1774, p=0.0000  , df=8
# likelihood ratio test: chi2=76.0692 , p=0.0000  , df=8
# parameter F test:         F=12.4620 , p=0.0000  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=11.2003 , p=0.0000  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=132.2005, p=0.0000  , df=9
# likelihood ratio test: chi2=78.0404 , p=0.0000  , df=9
# parameter F test:         F=11.2003 , p=0.0000  , df_denom=61, df_num=9
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.1082  , p=0.1502  , df_denom=85, df_num=1
# ssr based chi2 test:   chi2=2.1826  , p=0.1396  , df=1
# likelihood ratio test: chi2=2.1560  , p=0.1420  , df=1
# parameter F test:         F=2.1082  , p=0.1502  , df_denom=85, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.6259  , p=0.0785  , df_denom=82, df_num=2
# ssr based chi2 test:   chi2=5.5720  , p=0.0617  , df=2
# likelihood ratio test: chi2=5.4008  , p=0.0672  , df=2
# parameter F test:         F=2.6259  , p=0.0785  , df_denom=82, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8219  , p=0.1499  , df_denom=79, df_num=3
# ssr based chi2 test:   chi2=5.9501  , p=0.1141  , df=3
# likelihood ratio test: chi2=5.7533  , p=0.1242  , df=3
# parameter F test:         F=1.8219  , p=0.1499  , df_denom=79, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3113  , p=0.2734  , df_denom=76, df_num=4
# ssr based chi2 test:   chi2=5.8666  , p=0.2093  , df=4
# likelihood ratio test: chi2=5.6730  , p=0.2249  , df=4
# parameter F test:         F=1.3113  , p=0.2734  , df_denom=76, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2943  , p=0.2758  , df_denom=73, df_num=5
# ssr based chi2 test:   chi2=7.4466  , p=0.1895  , df=5
# likelihood ratio test: chi2=7.1349  , p=0.2108  , df=5
# parameter F test:         F=1.2943  , p=0.2758  , df_denom=73, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5207  , p=0.1841  , df_denom=70, df_num=6
# ssr based chi2 test:   chi2=10.8185 , p=0.0941  , df=6
# likelihood ratio test: chi2=10.1693 , p=0.1177  , df=6
# parameter F test:         F=1.5207  , p=0.1841  , df_denom=70, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4151  , p=0.2139  , df_denom=67, df_num=7
# ssr based chi2 test:   chi2=12.1231 , p=0.0966  , df=7
# likelihood ratio test: chi2=11.3065 , p=0.1258  , df=7
# parameter F test:         F=1.4151  , p=0.2139  , df_denom=67, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1736  , p=0.3288  , df_denom=64, df_num=8
# ssr based chi2 test:   chi2=11.8827 , p=0.1565  , df=8
# likelihood ratio test: chi2=11.0879 , p=0.1968  , df=8
# parameter F test:         F=1.1736  , p=0.3288  , df_denom=64, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0371  , p=0.4217  , df_denom=61, df_num=9
# ssr based chi2 test:   chi2=12.2407 , p=0.2001  , df=9
# likelihood ratio test: chi2=11.3900 , p=0.2499  , df=9
# parameter F test:         F=1.0371  , p=0.4217  , df_denom=61, df_num=9
#                  NETEXP       CIVPART           CPI         RWAGE  \
# NETEXP     0.000000e+00  7.710784e-04  5.785437e-03  4.240430e-03
# CIVPART    1.044257e-02  0.000000e+00  1.140852e-01  2.711547e-01
# CPI        5.288141e-10  2.971640e-04  0.000000e+00  2.132560e-08
# RWAGE      7.566672e-03  1.176192e-03  9.100202e-02  0.000000e+00
# POPGROWTH  1.136191e-03  6.223698e-15  2.294709e-05  2.418107e-11
# I_C        2.031800e-05  1.065014e-02  5.139997e-08  4.614171e-01
# RGDP       6.167754e-03  9.175847e-07  1.831687e-01  4.865032e-03
#
#               POPGROWTH       I_C          RGDP
# NETEXP     2.129007e-02  0.020836  1.497401e-04
# CIVPART    2.631581e-17  0.004814  1.517614e-02
# CPI        1.291708e-11  0.027712  4.286683e-06
# RWAGE      1.898202e-07  0.009607  2.838868e-03
# POPGROWTH  0.000000e+00  0.000031  4.625974e-21
# I_C        6.289553e-05  0.000000  1.388895e-01
# RGDP       4.181530e-24  0.061668  0.000000e+00

# %%
bvd.granger_score(G)
bvd.score_dict
# Out:
# {'NETEXP': {'Granger': np.int64(4)},
#  'CIVPART': {'Granger': np.int64(6)},
#  'CPI': {'Granger': np.int64(2)},
#  'RWAGE': {'Granger': np.int64(1)},
#  'POPGROWTH': {'Granger': np.int64(3)},
#  'I_C': {'Granger': np.int64(7)},
#  'RGDP': {'Granger': np.int64(5)}}

# %%
bvd.multivar_granger_matrix()

# %%
bvd.score_dict
# Out:
# {'NETEXP': {'Granger': np.int64(4), 'Multivar_Granger': np.int64(2)},
#  'CIVPART': {'Granger': np.int64(6), 'Multivar_Granger': np.int64(3)},
#  'CPI': {'Granger': np.int64(2), 'Multivar_Granger': np.int64(6)},
#  'RWAGE': {'Granger': np.int64(1), 'Multivar_Granger': np.int64(7)},
#  'POPGROWTH': {'Granger': np.int64(3), 'Multivar_Granger': np.int64(1)},
#  'I_C': {'Granger': np.int64(7), 'Multivar_Granger': np.int64(4)},
#  'RGDP': {'Granger': np.int64(5), 'Multivar_Granger': np.int64(5)}}
